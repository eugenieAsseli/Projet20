# %%
import segment
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, TiffTags
from segment import segment_base_sam

# %%
image_pil=Image.open('image.jpg')

# %%
plt.figure()
plt.imshow(image_pil)
plt.show()

# %% [markdown]
# Conversion en array

# %%
image=np.asarray(image_pil)

# %% [markdown]
# 1ere tentative de segmentation avec SAM

# %%
pps=64
pred_iou=0.98
stab_tresh=0.98

# %%
masks=segment_base_sam(image,print_objects=True,pps=pps,pred_iou=pred_iou,stab_tresh=stab_tresh)
# Out:
# cpu
